# %%
import numpy as np
import pandas as pd
import json
import ast

# %%
reference=pd.read_csv('csv/Reference.csv')

# %%
reference.describe()
# Out:
#              @id subject_is predicate_is object_is  reference_is
# count        352        352          352       352           352
# unique       352         47            8       250           292
# top     R5000379   R5000025          P54  R5000045  ['R5000997']
# freq           1        190          196        17             6

# %%
reference['reference_is']=reference['reference_is'].apply(lambda x:ast.literal_eval(x))

# %%
reference['num']=reference['reference_is'].apply(lambda x:len(x))

# %%
reference
# Out:
#           @id subject_is predicate_is  \
# 0    R5000095   R5000010          P18
# 1    R5000096   R5000010          P53
# 2    R5000097   R5000025          P53
# 3    R5000098   R5000025          P53
# 4    R5000099   R5000025          P55
# ..        ...        ...          ...
# 347  R5000442   R5000025          P54
# 348  R5000443   R5000025          P54
# 349  R5000444   R5000002          P18
# 350  R5000445   R5000016          P18
# 351  R5000446   R5000025          P54
#
#                                              object_is  \
# 0                                             R5000045
# 1                                             R5000025
# 2                                             R5000023
# 3                                             R5000033
# 4                                             R5000053
# ..                                                 ...
# 347                  Huanan South China Seafood Market
# 348  96% 34 identical at the whole genome level to ...
# 349                                           R5000045
# 350                                           R5000035
# 351                                              nCoV)
#
#                                           reference_is  num
# 0    [R5000447, R5000448, R5000449, R5000450, R5000...   45
# 1    [R5000492, R5000493, R5000494, R5000495, R5000...   29
# 2    [R5000521, R5000522, R5000523, R5000524, R5000...   12
# 3    [R5000532, R5000533, R5000534, R5000535, R5000...   16
# 4    [R5000548, R5000549, R5000550, R5000551, R5000...   63
# ..                                                 ...  ...
# 347                                         [R5001201]    1
# 348                                         [R5001202]    1
# 349                                         [R5001203]    1
# 350                                         [R5000787]    1
# 351                                         [R5001204]    1
#
# [352 rows x 6 columns]

# %%
items=pd.read_csv('csv/type.csv')
items=items[['@id','label']]
items=items.set_index('@id')['label']

# %%
label=items.to_dict()
label.keys()
# Out:
# dict_keys(['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'C22', 'C23', 'C24', 'C25', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37', 'P38', 'P39', 'P40', 'P41', 'P42', 'P43', 'P44', 'P45', 'P46', 'P47', 'P48', 'P49', 'P50', 'P51', 'P52', 'P53', 'P54', 'P55', 'P56', 'P57', 'P58', 'P59', 'P60', 'P61', 'P62', 'R5000001', 'R5000002', 'R5000003', 'R5000004', 'R5000005', 'R5000006', 'R5000007', 'R5000008', 'R5000009', 'R5000010', 'R5000011', 'R5000012', 'R5000013', 'R5000014', 'R5000015', 'R5000016', 'R5000017', 'R5000018', 'R5000019', 'R5000020', 'R5000021', 'R5000022', 'R5000023', 'R5000024', 'R5000025', 'R5000026', 'R5000027', 'R5000028', 'R5000029', 'R5000030', 'R5000031', 'R5000032', 'R5000033', 'R5000034', 'R5000035', 'R5000036', 'R5000037', 'R5000038', 'R5000039', 'R5000040', 'R5000041', 'R5000042', 'R5000043', 'R5000044', 'R5000045', 'R5000046', 'R5000047', 'R5000048', 'R5000049', 'R5000050', 'R5000051', 'R5000052', 'R5000053', 'R5000054', 'R5000055', 'R5000056', 'R5000057', 'R5000058', 'R5000059', 'R5000060', 'R5000061', 'R5000062', 'R5000063', 'R5000064', 'R5000065', 'R5000066', 'R5000067', 'R5000068', 'R5000069', 'R5000070', 'R5000071', 'R5000072', 'R5000073', 'R5000074', 'R5000075', 'R5000076', 'R5000077', 'R5000078', 'R5000079', 'R5000080', 'R5000081', 'R5000082', 'R5000083', 'R5000084', 'R5000085', 'R5000086', 'R5000087', 'R5000088', 'R5000089', 'R5000090', 'R5000091', 'R5000092', 'R5000093', 'R5000094', 'R5000095', 'R5000096', 'R5000097', 'R5000098', 'R5000099', 'R5000100', 'R5000101', 'R5000102', 'R5000103', 'R5000104', 'R5000105', 'R5000106', 'R5000107', 'R5000108', 'R5000109', 'R5000110', 'R5000111', 'R5000112', 'R5000113', 'R5000114', 'R5000115', 'R5000116', 'R5000117', 'R5000118', 'R5000119', 'R5000120', 'R5000121', 'R5000122', 'R5000123', 'R5000124', 'R5000125', 'R5000126', 'R5000127', 'R5000128', 'R5000129', 'R5000130', 'R5000131', 'R5000132', 'R5000133', 'R5000134', 'R5000135', 'R5000136', 'R5000137', 'R5000138', 'R5000139', 'R5000140', 'R5000141', 'R5000142', 'R5000143', 'R5000144', 'R5000145', 'R5000146', 'R5000147', 'R5000148', 'R5000149', 'R5000150', 'R5000151', 'R5000152', 'R5000153', 'R5000154', 'R5000155', 'R5000156', 'R5000157', 'R5000158', 'R5000159', 'R5000160', 'R5000161', 'R5000162', 'R5000163', 'R5000164', 'R5000165', 'R5000166', 'R5000167', 'R5000168', 'R5000169', 'R5000170', 'R5000171', 'R5000172', 'R5000173', 'R5000174', 'R5000175', 'R5000176', 'R5000177', 'R5000178', 'R5000179', 'R5000180', 'R5000181', 'R5000182', 'R5000183', 'R5000184', 'R5000185', 'R5000186', 'R5000187', 'R5000188', 'R5000189', 'R5000190', 'R5000191', 'R5000192', 'R5000193', 'R5000194', 'R5000195', 'R5000196', 'R5000197', 'R5000198', 'R5000199', 'R5000200', 'R5000201', 'R5000202', 'R5000203', 'R5000204', 'R5000205', 'R5000206', 'R5000207', 'R5000208', 'R5000209', 'R5000210', 'R5000211', 'R5000212', 'R5000213', 'R5000214', 'R5000215', 'R5000216', 'R5000217', 'R5000218', 'R5000219', 'R5000220', 'R5000221', 'R5000222', 'R5000223', 'R5000224', 'R5000225', 'R5000226', 'R5000227', 'R5000228', 'R5000229', 'R5000230', 'R5000231', 'R5000232', 'R5000233', 'R5000234', 'R5000235', 'R5000236', 'R5000237', 'R5000238', 'R5000239', 'R5000240', 'R5000241', 'R5000242', 'R5000243', 'R5000244', 'R5000245', 'R5000246', 'R5000247', 'R5000248', 'R5000249', 'R5000250', 'R5000251', 'R5000252', 'R5000253', 'R5000254', 'R5000255', 'R5000256', 'R5000257', 'R5000258', 'R5000259', 'R5000260', 'R5000261', 'R5000262', 'R5000263', 'R5000264', 'R5000265', 'R5000266', 'R5000267', 'R5000268', 'R5000269', 'R5000270', 'R5000271', 'R5000272', 'R5000273', 'R5000274', 'R5000275', 'R5000276', 'R5000277', 'R5000278', 'R5000279', 'R5000280', 'R5000281', 'R5000282', 'R5000283', 'R ...

# %%
prop=pd.read_csv('csv/property.csv')
prop=prop[['@id','label']].set_index('@id')['label']
prop
# Out:
# @id
# P1          species
# P2            genus
# P3         subGenus
# P4           family
# P5        subFamily
#            ...
# P58      subject_is
# P59       object_is
# P60    predicate_is
# P61    reference_is
# P62           title
# Name: label, Length: 62, dtype: object

# %%
props=prop.to_dict()
props.keys()
# Out:
# dict_keys(['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37', 'P38', 'P39', 'P40', 'P41', 'P42', 'P43', 'P44', 'P45', 'P46', 'P47', 'P48', 'P49', 'P50', 'P51', 'P52', 'P53', 'P54', 'P55', 'P56', 'P57', 'P58', 'P59', 'P60', 'P61', 'P62'])

# %%
def getvalue(x,dictionary):
    if(x in dictionary):
        return dictionary[x]
    else:
        return x

# %%
reference.subject_is=reference.subject_is.apply(lambda x:getvalue(x,label))

# %%
reference.predicate_is=reference.predicate_is.apply(lambda x:getvalue(x,props))

# %%
reference.object_is=reference.object_is.apply(lambda x:getvalue(x,label))

# %%
reference
# Out:
#           @id                       subject_is               predicate_is  \
# 0    R5000095                         SARS-CoV                    produce
# 1    R5000096                         SARS-CoV                 similarity
# 2    R5000097                       SARS-CoV-2                 similarity
# 3    R5000098                       SARS-CoV-2                 similarity
# 4    R5000099                       SARS-CoV-2  virus_protein_interaction
# ..        ...                              ...                        ...
# 347  R5000442                       SARS-CoV-2                property_is
# 348  R5000443                       SARS-CoV-2                property_is
# 349  R5000444  porcine epidemic diarrhea virus                    produce
# 350  R5000445                   Bat-SL-CoVZC45                    produce
# 351  R5000446                       SARS-CoV-2                property_is
#
#                                              object_is  \
# 0                                                Spike
# 1                                           SARS-CoV-2
# 2                                     Beta coronavirus
# 3                                             MERS-CoV
# 4                                                 ACE2
# ..                                                 ...
# 347                  Huanan South China Seafood Market
# 348  96% 34 identical at the whole genome level to ...
# 349                                              Spike
# 350                                                  E
# 351                                              nCoV)
#
#                                           reference_is  num
# 0    [R5000447, R5000448, R5000449, R5000450, R5000...   45
# 1    [R5000492, R5000493, R5000494, R5000495, R5000...   29
# 2    [R5000521, R5000522, R5000523, R5000524, R5000...   12
# 3    [R5000532, R5000533, R5000534, R5000535, R5000...   16
# 4    [R5000548, R5000549, R5000550, R5000551, R5000...   63
# ..                                                 ...  ...
# 347                                         [R5001201]    1
# 348                                         [R5001202]    1
# 349                                         [R5001203]    1
# 350                                         [R5000787]    1
# 351                                         [R5001204]    1
#
# [352 rows x 6 columns]

# %%
def count(x):
    x = np.array(x)
    x= np.unique(x)
    return len(x)

# %%
reference_virus=reference.groupby('subject_is')['reference_is'].sum().apply(lambda x:count(x)).to_frame()
minor_virus=reference_virus['reference_is']<8
others=reference_virus[minor_virus].sum()
reference_virus.drop(reference_virus[minor_virus].index, inplace=True)
reference_virus.loc['others']=int(others.values)
reference_virus['num_refer']=reference_virus['reference_is']
del reference_virus['reference_is']
reference_virus.sort_values(by='num_refer',ascending=False)
# Out:
#                    num_refer
# subject_is
# SARS-CoV-2               470
# SARS-CoV                 162
# others                    74
# Coronaviruses             49
# Spike                     49
# MERS-CoV                  27
# nelfinavir                12
# Bat coronavirus            8
# bat SARS-CoV-like          8

# %%
plot = reference_virus.plot.pie(y='num_refer',figsize=(16, 20),title='the popularitiy of virus in references',autopct='%1.1f%%')
fig = plot.get_figure()
fig.savefig("img/virus.svg")

# %%
reference_obj=reference.groupby('object_is')['reference_is'].sum().apply(lambda x:count(x)).to_frame()
minor_obj=reference_obj['reference_is']<8
others=reference_obj[minor_obj].sum()
reference_obj.drop(reference_obj[minor_obj].index, inplace=True)
reference_obj.loc['others']=int(others.values)
reference_obj['num_refer']=reference_obj['reference_is']
del reference_obj['reference_is']
reference_obj.sort_values(by='num_refer',ascending=False)
reference_obj
# Out:
#                              num_refer
# object_is
# ACE2                               132
# Bat SARS-like Coronaviruses          9
# Bat coronavirus                     14
# Bat-SL-CoVZC45                      10
# Beta coronavirus                    13
# E                                   15
# MERS-CoV                            25
# Mpro                                88
# N                                   18
# Nsp3                                32
# SARS-CoV                            56
# SARS-CoV-2                          48
# Spike                              119
# pneumonia                           33
# others                             310

# %%
plot = reference_obj.plot.pie(y='num_refer',figsize=(20, 20),title='the popular study objects in references',autopct='%1.1f%%')
fig = plot.get_figure()
fig.savefig("img/object.svg")

# %%
Filename='relation.json'
with open(Filename,encoding='utf_8_sig', errors='ignore') as read_file:
    data = json.load(read_file)

# %%
data.keys()
# Out:
# dict_keys(['links', 'nodes'])

# %%
relation=dict()
relation['links']=[]
relation['nodes']=[]

# %%
virus_ref=reference.groupby('subject_is')['reference_is'].sum().apply(lambda x:count(x)).to_frame()['reference_is']
virus_weight=virus_ref.to_dict()
virus_weight
# Out:
# {'B-M27-VME': 1,
#  'Bat SARS-CoV': 3,
#  'Bat SARS-like Coronaviruses': 2,
#  'Bat coronavirus': 8,
#  'Bat-SL-CoVZC45': 1,
#  'Beta coronavirus': 4,
#  'Bictegravir': 1,
#  'CR3022': 2,
#  'Coronaviruses': 49,
#  'HCoVs': 1,
#  'HIV': 1,
#  'MERS-CoV': 27,
#  'MERS-CoV-specific human monoclonal antibody m336': 1,
#  'Murine coronavirus': 1,
#  'Prulifloxacin': 1,
#  'SARS-CoV': 162,
#  'SARS-CoV BJ01': 1,
#  'SARS-CoV antibody': 4,
#  'SARS-CoV-2': 470,
#  'SARS-CoV-like Coronaviruses': 4,
#  'SARS-related CoVs': 2,
#  'Sofosbuvir/Velpatasvir': 2,
#  'Spike': 49,
#  'antibody m396': 1,
#  'bat SARS CoV W1V1': 1,
#  'bat SARS-CoV-like': 8,
#  'bat-SL-CoVZX45': 1,
#  'bat-associated betacoronavirus': 1,
#  'colistin': 2,
#  'eszopiclone': 1,
#  'feline coronavirus': 1,
#  'gamma-CoVs': 1,
#  'lentiviruses': 3,
#  'lopinavir': 6,
#  'lopinavir/ritonavir': 4,
#  'monoclonal antibody': 2,
#  'mouse hepatitis virus': 1,
#  'murine hepatitis virus': 1,
#  'nelfinavir': 12,
#  'neutralizing antibody m396': 1,
#  'perampanel': 2,
#  'pitavastatin': 2,
#  'porcine epidemic diarrhea virus': 1,
#  'praziquantel': 2,
#  'ritonavir': 6,
#  'sarbeco virus': 1,
#  'zopiclone': 1}

# %%
obj_weight=reference.groupby('object_is')['reference_is'].sum().apply(lambda x:count(x)).to_frame()['reference_is'].to_dict()
obj_weight
# Out:
# {'(deposited in GenBank with the accession number MN908947 ) by Professor Yong-Zhen Zhang from The Shanghai Public Health Clinical Center & School of Public Health, and scientists from the partner institutions including the Central Hospital of Wuhan, Huazhong University of Science and Technology, the Wuhan Center for Disease Control and Prevention, the National Institute for Communicable Disease Control and Prevention, Chinese Center for Disease Control, and the University of Sydney, Sydney, Australia.': 1,
#  '16 proteins, and four structural proteins': 1,
#  '2020) was analysed with our tool and compared with the 2019-nCOv WH_Human1_China_2019Dec strain': 1,
#  '20200202-sitrep-13-ncov-v3.pdf': 1,
#  '360 grown from Vero E6': 1,
#  '4 genera Alphacoronavirus (α-CoV)': 1,
#  '4.8days': 1,
#  '96% 34 identical at the whole genome level to a bat coronavirus': 1,
#  '96% identical at the whole genome level to a bat coronavirus': 1,
#  'A newly identified coronavirus': 1,
#  'ACE2': 132,
#  'Asia-Pacific Region': 1,
#  'Bat SARS-CoV': 2,
#  'Bat SARS-like Coronaviruses': 9,
#  'Bat coronavirus': 14,
#  'Bat-SL-CoVZC45': 10,
#  'Bat-SL-CoVZXC21': 5,
#  'Beta coronavirus': 13,
#  'Betacoronavirus (β-CoV),': 1,
#  'Betacoronavirus genera': 1,
#  'Betacoronavirus genus': 1,
#  'COVID-19': 4,
#  'Coronavirus': 1,
#  'Coronaviruses': 2,
#  'DPP4': 1,
#  'Deltacoronavirus (δ-CoV)': 1,
#  'E': 15,
#  'Embecovirus, ρ = 0.59; (b) Merbecovirus, ρ = 0.64; (c) Nobecovirus, ρ= 0.54 and (d) Sarbecovirus': 1,
#  'Gammacoronavirus (γ-CoV)': 1,
#  'Gralinski, L. E. and Menachery, V. D. Return of the Coronavirus': 1,
#  'Huanan South China Seafood Market': 1,
#  'Japan (JPN) and Asia-Pacific Region': 1,
#  'K J481931.Chaos plot vertices are assigned top left Cytosine': 1,
#  'MERS': 1,
#  'MERS-CoV': 25,
#  'Menachery, V. D. Return of the Coronavirus': 1,
#  'Merbecovirus, ρ = 0.64; (c) Nobecovirus, ρ= 0.54 and (d) Sarbecovirus': 1,
#  'Mpro': 88,
#  'N': 18,
#  'NC 4.0 International license.perpetuity.Preliminary identification of potential vaccine targets for 2019-nCoV based on SARS-CoV immunological studies Syed Faraz Ahmed1#, Ahmed A. Quadeer1,#,*, and Matthew R. McKay1,2,* 1Department of Electronic and Computer Engineering, The Hong Kong University of Science and Technology, Hong Kong, China': 1,
#  'NC_045512.2': 1,
#  'National Institute for Communicable Disease Control and Prevention (ICDC) Chinese Center for Disease Control and Prevention (China CDC), Institute of Pathogen Biology, Chinese Academy of Medical Sciences & Peking Union Medical College, Hubei Provincial Center for Disease Control and Prevention, Wuhan Institute of Virology, Chinese Academy of Sciences, National Institute for Viral Disease Control and Prevention, China CDC, Li Ka Shing Faculty of Medicine, The University of Hong Kong': 1,
#  'Novel Coronavirus (2019-nCoV) 2020': 1,
#  'Nsp1': 1,
#  'Nsp3': 32,
#  'Nsp7': 1,
#  'O-acetylated sialic acid': 1,
#  'ORF10': 1,
#  'ORF1a': 4,
#  'ORF1ab': 5,
#  'ORF1b': 4,
#  'ORF3a': 1,
#  'ORF6': 1,
#  'ORF7a': 1,
#  'ORF8': 6,
#  'PDF-2180 28 , 29': 1,
#  'RBD': 2,
#  'RNA viruses, coronavirus genomes are known to have genomic plasticity': 1,
#  'Return of the Coronavirus': 1,
#  'SARS': 1,
#  'SARS coronavirus': 2,
#  'SARS related coronaviruses (SARSr-CoV': 1,
#  'SARS virus': 1,
#  'SARS-CoV': 56,
#  'SARS-CoV-2': 48,
#  'SARS-CoV-like Coronaviruses': 7,
#  'SARS-CoV-like virus': 1,
#  'SARS-like coro-naviruses from bats': 1,
#  'SARS-related CoVs': 1,
#  'Sarbecovirus': 4,
#  'Snakes had been proposed as an intermediary hostfor': 1,
#  'South Korea': 3,
#  'Spike': 119,
#  'TMPRSS2': 3,
#  'The basic reproduction number ( R 0 ) was calculated from the RP model to assess the transmissibility': 1,
#  'Transmissibility': 1,
#  'USA (n=5), France (n=2), Thailand (n=2), Japan (n=1) and Taiwan (n=1) were correctly classified at phylogenetic cluster level as 2019-nCoV, which may be renamed as SARS-B': 1,
#  'Western blot': 1,
#  'Wuhan of China': 1,
#  'Wuhan pneumonia': 1,
#  'a new type of bat coronavirus': 1,
#  'able to infect human': 1,
#  'acute respiratory syndrome': 1,
#  'among the families of the Riboviria realm': 1,
#  'an infectious disease with a latent period': 1,
#  'antibodies in one patient 255 who showed sign of disease on 2019.12.23': 1,
#  'arealso known to use a template switching mechanism which can contribute to high rates of homologousRNA recombination between their viral genomes': 1,
#  'arose from recombination between clade 1': 1,
#  'atypical pneumonia': 2,
#  'bat SARS like coronavirus and bat coronavirus': 1,
#  'bat SARS-CoV-like': 6,
#  'bat SARSr-CoV WIV1': 1,
#  'bat SARSr-Cov': 1,
#  'bat and unknowncoronaviruses': 1,
#  'bat coronavirus RaTG13': 2,
#  'bat origin': 4,
#  'bat-SL-CoVZX21': 4,
#  'bat-SL-CoVZX45': 2,
#  'bat-like SARS coronavirus': 1,
#  'bats': 3,
#  'batsfrom china': 1,
#  'belong to a novel type of bat coronavirus': 1,
#  'belong to lineage B (Sarbecovirus) of Betacoronavirus': 1,
#  'belong to the Riboviria realm': 1,
#  'belonging to the realm Riboviria': 1,
#  'belongs to the Betacoronavirus': 1,
#  'belongs to the Betacoronavirus genus': 2,
#  'beta-coronavirus': 1,
#  'betacoronavirus': 3,
#  'betacoronaviruses': 1,
#  'blue circles, other genomes as grey diamonds': 1,
#  'can be transmitted through the digestive tract': 1,
#  'canonical structural proteins: spike, envelope, membrane, and nucleocapsid': 1,
#  'carrying 30 kilobase of single positive-sense RNA genome': 1,
#  'cell tropism': 1,
#  'civet cats': 1,
#  'closest to the Sarbecovirus': 1,
#  'common cold': 2,
#  'comparatively more recurrent': 1,
#  'complete genome sequences from the Global Initiative for Sharing all Influenza Data (Gisaid [7]) and from GenBank': 1,
#  'contagious, but E-status is also contagious.': 1,
#  'coronary appearance': 1,
#  'coronaviruses': 1,
#  'coronaviruses in bats from Kenya': 1,
#  'cough': 1,
#  'could spread globally [ 3 , 5 , 19 , 20 ] with sustained transmission in countries around the world': 1,
#  'death': 2,
#  'death rate of 2.2%': 2,
#  'did not originate from other animal hosts': 1,
#  'digestive tract': 1,
#  'discoveredin bats across China, and even in European, African and other Asian countries': 1,
#  'dsRNA sensors': 1,
#  'emerged from Wuhan, China': 1,
#  'enveloped': 1,
#  'epidemic': 1,
#  'epidemic of acute respiratory syndrome in humans': 2,
#  'epitopes displayed by HLA-DR alleles predominantly present in the ethnic populations of China (PRC), Thailand (TH), Japan (JPN) and Asia-Pacific Region': 1,
#  'exhibited potential to cause human infection': 1,
#  'facemask': 1,
#  'fatality rate of 2%': 1,
#  'from the genusBetacoronavirus': 1,
#  'gastrointestinal diseases': 1,
#  'genes shared less than 80% nt sequence 78 identity to SARS-CoV': 1,
#  'genetically distant from the human SARS virus': 1,
#  'genetically distinct species of Sarbecovirus': 1,
#  'genetically fairly distant from the human SARS coronavirus': 1,
#  'genome of 29903 bp': 1,
#  'genomic plasticity': 1,
#  'genomic similarityto the sub-genus Sarbecovirus corroborates a possible bat origin': 1,
#  'grey diamonds': 1,
#  'has infected 2,494 individuals in 27 countries since 2012, 858 of them died': 1,
#  'healthcare system during the 2019-nCoV outbreak in Wuhan, China': 1,
#  'human respiratory disease': 2,
#  'human to human transmission and severe human infection has been recently reported from the city of Wuhan in China': 1,
#  'human to human transmission and severe human infection has been recently reported from the city of Wuhan in the Hubei province in China': 1,
#  'humoral and cell-mediated immune responses.': 1,
#  'includes enveloped viruses with large (~30kb), positive-sense single-stranded RNA genomes': 1,
#  'infect avian species': 1,
#  'infect human': 1,
#  'is likely a new type of bat coronavirus': 1,
#  'isolated 37 from the bronchoalveolar lavage fluid of a critically ill patient, which can be 38 neutralized by sera from several patients': 1,
#  'isolated from a man died of severe pneumonia and organ failure in Saudi Arabia at June 2012': 1,
#  'isolated from one of the pneumonia patients': 1,
#  'isolated from the airway epithelial cells': 1,
#  'isolated from the bronchoalveolar lavage fluid of a critically ill patient, which can be neutralized by sera from several patients': 1,
#  'isolated from the human airway epithelial cells': 1,
#  'isolated in China (n=36), USA (n=5), France (n=2), Thailand (n=2), Japan (n=1) and Taiwan (n=1) were correctly classified at phylogenetic cluster level as 2019-nCoV, which may be renamed as SARS-B': 1,
#  'isolated in China and around the world': 1,
#  'its first victim in Foshan, mainland China, and soon spread to all over the country by travelling with potential patients': 1,
#  'large swaths of genetic material at once 34 , 35': 1,
#  'lied at the interface between bat SARS like coronavirus and bat coronavirus': 1,
#  'lineage B betacoronavirus': 1,
#  'liver damage': 1,
#  'm.mckay@ust.hk': 1,
#  'mainly found in bats': 1,
#  'may be transmitted through airway': 1,
#  'may representa genetically distinct species of Sarbecovirus': 1,
#  'members of the family Coronaviridae and subfamily Coronavirinae': 1,
#  'might be imported to the seafood market in a short time': 1,
#  'might have originated from bat, but the intermediate transmission vehicle is not known at this stage': 1,
#  'mink may be two candidate reservoirs of 2019-nCov': 1,
#  'more likely a new type of bat coronavirus': 1,
#  'nCoV)': 1,
#  'no SNPs on the two predicted ORFs, they have two nonsynonymous SNPs on ymdB, which indicates that these 2019-nCoV may derived from one origin': 1,
#  'non-medical scholars who use mathematics and computer technology to simulate and predict disease transmission.': 1,
#  'not only I-status is contagious, but E-status is also contagious.': 1,
#  'not-mosaic consisting in almost half of its genome of a distinct lineage within the betacoronavirus': 1,
#  'novel Coronavirus (2019-nCov)': 1,
#  'novel coronavirus': 4,
#  'novel coronavirus emerged in Wuhan, China': 1,
#  'occurred in Saudi Arabia in 2012': 1,
#  'operating in bats as a host reservoir for coronaviruses': 1,
#  'origin from bats': 1,
#  'originate from bats': 1,
#  'originated in bats': 1,
#  'originating from bats': 1,
#  'originating from the province of Wuhan, China': 1,
#  'outbreak in South Korea': 1,
#  'outbreak in Wuhan, China': 1,
#  'part of the Sarbecovirus sub-genus': 1,
#  'part of the sub-genusSarbecovirus': 1,
#  'pathogen transmissibility': 1,
#  'pneumonia': 33,
#  'positive single-stranded RNA virus': 1,
#  'positive stranded RNA viruses': 1,
#  'positive-sense': 1,
#  'positive-sense enveloped RNA viruses': 1,
#  'positive-sense single-stranded RNA viruses': 1,
#  'raccoon dogs': 1,
#  'represents the third major zoonotic human coronavirus of this century': 1,
#  'sarbeco virus': 7,
#  'seasonal influenza': 1,
#  'seventh novel human betacoronavirus': 1,
#  'severe and potential fatal respiratory tract infections': 1,
#  'severe human infection has been recently reported from the city of Wuhan in China': 1,
#  'severe humanrespiratory disease': 1,
#  'severe pneumonia': 2,
#  'severe pneumonia in patients with weaker immune system': 1,
#  'severe respiratory disease': 1,
#  'severe respiratory diseases in afflicted human patients': 1,
#  'severe respiratory infection': 2,
#  'severe, and often fatal, respiratory illness': 1,
#  'should belong to a novel type of bat coronavirus': 1,
#  'significant threats to public health': 1,
#  'similarly transmissible to the SARS coronavirus': 1,
#  'single positive-stranded RNA viruses belonging to Coronaviridae family1, which are divided into four genera: Alpha-, Beta-, Delta- and Gamma-coronavirus': 1,
#  'single strand RNA viruses': 1,
#  'single-stranded positive-sense RNA viruses': 1,
#  'strong potential to infect human': 1,
#  'submitted on GISAID': 1,
#  'suggesting that this new coronavirus originated from bat': 1,
#  'the causative agent of the outbreak': 1,
#  'the largest genomes ranging from 26 to 32 kb in length': 1,
#  'the sequence (accession#: MN908947 )': 1,
#  'the species of SARS related coronaviruses (SARSr-CoV': 1,
#  'three core genes: two ORFs and one functional gene ymdB': 1,
#  'transmissibility': 1,
#  'trypsin': 1,
#  'two SARS-like coro-naviruses from bats': 1,
#  'two SARSr-CoV sampled from Rhinolophus sinicus bats in Zhoushan, China': 1,
#  'two nonsynonymous SNPs on ymdB, which indicates that these 2019-nCoV may derived from one origin': 1,
#  'typical of lineageB (Sarbecovirus) Betacoronaviruses': 1,
#  'unknown animals': 1,
#  'unknowncoronaviruses': 1,
#  'upper respiratory, gastrointestinal and central nervous system in humans': 1,
#  'viruses': 1,
#  'wearing respirator in the public': 1,
#  'withcoronaviruses thought to have ancient origins and recent crossover events that can lead to cross-speciesinfection': 1,
#  '“2019-nCoV”, was discovered from Wuhan Viral Pneumonia cases in December 2019, and was named by the World Health Organization on January 12, 2020.': 2}

# %%
edges=['CAUSE','EFFECT','TARGET','BINDING','INTERACTION','PRODUCE','SIMILAR']
edge=dict(zip(edges,[i for i in range(7)]))

# %%
edge
# Out:
# {'CAUSE': 0,
#  'EFFECT': 1,
#  'TARGET': 2,
#  'BINDING': 3,
#  'INTERACTION': 4,
#  'PRODUCE': 5,
#  'SIMILAR': 6}

# %%
records=pd.read_csv('csv/export.csv')
classes=pd.read_csv('csv/type.csv')

# %%
records
# Out:
#                                                      a  type(r)  \
# 0    {"label":neutralizing antibody m396,"id":R5000...   EFFECT
# 1    {"id":R5000055,"label":ritonavir,"target":['R5...   TARGET
# 2    {"id":R5000055,"label":ritonavir,"target":['R5...   TARGET
# 3    {"id":R5000056,"label":zopiclone,"target":['R5...   TARGET
# 4    {"id":R5000057,"label":colistin,"target":['R50...   TARGET
# ..                                                 ...      ...
# 151                   {"id":R5000033,"label":MERS-CoV}    CAUSE
# 152                   {"id":R5000033,"label":MERS-CoV}    CAUSE
# 153                      {"id":R5000045,"label":Spike}  BINDING
# 154                      {"id":R5000045,"label":Spike}  BINDING
# 155                      {"id":R5000045,"label":Spike}  BINDING
#
#                                                      c
# 0                     {"id":R5000010,"label":SARS-CoV}
# 1                         {"id":R5000038,"label":Nsp3}
# 2                         {"id":R5000036,"label":Mpro}
# 3                         {"id":R5000036,"label":Mpro}
# 4                         {"id":R5000036,"label":Mpro}
# ..                                                 ...
# 151                   {"id":R5000076,"label":epidemic}
# 152  {"id":R5000084,"label":severe and potential fa...
# 153                       {"id":R5000053,"label":ACE2}
# 154   {"label":O-acetylated sialic acid,"id":R5000050}
# 155                    {"id":R5000049,"label":trypsin}
#
# [156 rows x 3 columns]

# %%
def find_label(x):
    return x.split('label":')[1].split(',')[0].split('}')[0]

# %%
def find_id(x):
    return x.split('id":')[1].split(',')[0].split('}')[0]

# %%
def find_weight(x):
    weight=0
    if(x in virus_weight):
        weight=max(weight,virus_weight[x])
    if(x in obj_weight):
        weight=max(weight,obj_weight[x])
    weight=np.log(weight+1)
    return weight

# %%
records['a']=records['a'].apply(lambda x:find_label(x))
records['c']=records['c'].apply(lambda x:find_label(x))

# %%
records['type(r)']=records['type(r)'].apply(lambda x:edge[x])

# %%
edge
# Out:
# {'CAUSE': 0,
#  'EFFECT': 1,
#  'TARGET': 2,
#  'BINDING': 3,
#  'INTERACTION': 4,
#  'PRODUCE': 5,
#  'SIMILAR': 6}

# %%
records['source']=records['a']
records['type']=records['type(r)']
records['target']=records['c']
del records['a']
del records['c']
del records['type(r)']
records
# Out:
#                          source  type  \
# 0    neutralizing antibody m396     1
# 1                     ritonavir     2
# 2                     ritonavir     2
# 3                     zopiclone     2
# 4                      colistin     2
# ..                          ...   ...
# 151                    MERS-CoV     0
# 152                    MERS-CoV     0
# 153                       Spike     3
# 154                       Spike     3
# 155                       Spike     3
#
#                                                 target
# 0                                             SARS-CoV
# 1                                                 Nsp3
# 2                                                 Mpro
# 3                                                 Mpro
# 4                                                 Mpro
# ..                                                 ...
# 151                                           epidemic
# 152  severe and potential fatal respiratory tract i...
# 153                                               ACE2
# 154                           O-acetylated sialic acid
# 155                                            trypsin
#
# [156 rows x 3 columns]

# %%
relation['links']=list(records.T.to_dict().values())

# %%
relation['links']
# Out:
# [{'source': 'neutralizing antibody m396', 'type': 1, 'target': 'SARS-CoV'},
#  {'source': 'ritonavir', 'type': 2, 'target': 'Nsp3'},
#  {'source': 'ritonavir', 'type': 2, 'target': 'Mpro'},
#  {'source': 'zopiclone', 'type': 2, 'target': 'Mpro'},
#  {'source': 'colistin', 'type': 2, 'target': 'Mpro'},
#  {'source': 'pitavastatin', 'type': 2, 'target': 'Mpro'},
#  {'source': 'pitavastatin', 'type': 1, 'target': 'SARS-CoV-2'},
#  {'source': 'Bictegravir', 'type': 2, 'target': 'Mpro'},
#  {'source': 'praziquantel', 'type': 2, 'target': 'Mpro'},
#  {'source': 'praziquantel', 'type': 1, 'target': 'SARS-CoV-2'},
#  {'source': 'lopinavir', 'type': 2, 'target': 'Nsp3'},
#  {'source': 'lopinavir', 'type': 2, 'target': 'Mpro'},
#  {'source': 'antibody m396', 'type': 2, 'target': 'Spike'},
#  {'source': 'monoclonal antibody', 'type': 2, 'target': 'Spike'},
#  {'source': 'monoclonal antibody', 'type': 1, 'target': 'SARS-CoV'},
#  {'source': 'SARS-CoV antibody', 'type': 2, 'target': 'Spike'},
#  {'source': 'SARS-CoV antibody', 'type': 1, 'target': 'SARS-CoV-2'},
#  {'source': 'SARS-CoV antibody', 'type': 1, 'target': 'SARS-CoV'},
#  {'source': 'lopinavir/ritonavir', 'type': 2, 'target': 'Mpro'},
#  {'source': 'B-M27-VME', 'type': 2, 'target': 'Nsp3'},
#  {'source': 'CR3022', 'type': 2, 'target': 'Spike'},
#  {'source': 'CR3022', 'type': 1, 'target': 'SARS-CoV-2'},
#  {'source': 'perampanel', 'type': 2, 'target': 'Mpro'},
#  {'source': 'perampanel', 'type': 1, 'target': 'SARS-CoV-2'},
#  {'source': 'Prulifloxacin', 'type': 2, 'target': 'Mpro'},
#  {'source': 'MERS-CoV-specific human monoclonal antibody m336',
#   'type': 2,
#   'target': 'Spike'},
#  {'source': 'Sofosbuvir/Velpatasvir', 'type': 1, 'target': 'MERS-CoV'},
#  {'source': 'Sofosbuvir/Velpatasvir', 'type': 1, 'target': 'SARS-CoV-2'},
#  {'source': 'Sofosbuvir/Velpatasvir', 'type': 1, 'target': 'Coronaviruses'},
#  {'source': 'eszopiclone', 'type': 2, 'target': 'Mpro'},
#  {'source': 'nelfinavir', 'type': 2, 'target': 'Mpro'},
#  {'source': 'nelfinavir', 'type': 1, 'target': 'Coronaviruses'},
#  {'source': 'nelfinavir', 'type': 1, 'target': 'SARS-CoV-2'},
#  {'source': 'porcine epidemic diarrhea virus', 'type': 5, 'target': 'Spike'},
#  {'source': 'Murine coronavirus', 'type': 5, 'target': 'Nsp3'},
#  {'source': 'Coronaviruses', 'type': 0, 'target': 'severe'},
#  {'source': 'Coronaviruses', 'type': 0, 'target': 'common cold'},
#  {'source': 'Coronaviruses', 'type': 0, 'target': 'severe pneumonia'},
#  {'source': 'Coronaviruses', 'type': 0, 'target': 'gastrointestinal diseases'},
#  {'source': 'Coronaviruses', 'type': 4, 'target': 'ACE2'},
#  {'source': 'Coronaviruses', 'type': 5, 'target': 'Nsp3'},
#  {'source': 'Coronaviruses', 'type': 5, 'target': 'Mpro'},
#  {'source': 'Coronaviruses', 'type': 5, 'target': 'E'},
#  {'source': 'Coronaviruses', 'type': 5, 'target': 'ORF1a'},
#  {'source': 'Coronaviruses', 'type': 5, 'target': 'ORF1ab'},
#  {'source': 'Coronaviruses', 'type': 5, 'target': 'ORF1b'},
#  {'source': 'Coronaviruses', 'type': 5, 'target': 'Spike'},
#  {'source': 'Coronaviruses', 'type': 6, 'target': 'MERS-CoV'},
#  {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'bat-SL-CoVZX21'},
#  {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'SARS-CoV'},
#  {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'Bat coronavirus'},
#  {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'bat-SL-CoVZX45'},
#  {'source': 'bat SARS-CoV-like', 'type': 5, 'target': 'Spike'},
#  {'source': 'bat SARS-CoV-like', 'type': 4, 'target': 'ACE2'},
#  {'source': 'SARS-CoV', 'type': 0, 'target': 'severe respiratory disease'},
#  {'source': 'SARS-CoV',
#   'type': 0,
#   'target': 'severe respiratory diseases in afflicted human patients'},
#  {'source': 'SARS-CoV', 'type': 0, 'target': 'epidemic'},
#  {'source': 'SARS-CoV', 'type': 0, 'target': 'SARS'},
#  {'source': 'SARS-CoV', 'type': 4, 'target': 'TMPRSS2'},
#  {'source': 'SARS-CoV', 'type': 4, 'target': 'ACE2'},
#  {'source': 'SARS-CoV', 'type': 5, 'target': 'Spike'},
#  {'source': 'SARS-CoV', 'type': 5, 'target': 'ORF1ab'},
#  {'source': 'SARS-CoV', 'type': 5, 'target': 'Nsp3'},
#  {'source': 'SARS-CoV', 'type': 5, 'target': 'E'},
#  {'source': 'SARS-CoV', 'type': 5, 'target': 'Nsp1'},
#  {'source': 'SARS-CoV', 'type': 5, 'target': 'Mpro'},
#  {'source': 'SARS-CoV', 'type': 5, 'target': 'N'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'Bat-SL-CoVZC45'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'Bat SARS-CoV'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'MERS-CoV'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'Bat-SL-CoVZXC21'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'Beta coronavirus'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'SARS-CoV-2'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'bat SARS-CoV-like'},
#  {'source': 'SARS-CoV', 'type': 6, 'target': 'SARS-CoV-like Coronaviruses'},
#  {'source': 'murine hepatitis virus', 'type': 5, 'target': 'Nsp3'},
#  {'source': 'bat SARS CoV W1V1', 'type': 4, 'target': 'ACE2'},
#  {'source': 'sarbeco virus', 'type': 5, 'target': 'Spike'},
#  {'source': 'Bat-SL-CoVZC45', 'type': 5, 'target': 'Nsp7'},
#  {'source': 'Bat-SL-CoVZC45', 'type': 5, 'target': 'E'},
#  {'source': 'bat-associated betacoronavirus', 'type': 4, 'target': 'ACE2'},
#  {'source': 'SARS-CoV BJ01', 'type': 6, 'target': 'bat SARSr-CoV WIV1'},
#  {'source': 'mouse hepatitis virus', 'type': 5, 'target': 'Nsp3'},
#  {'source': 'Bat SARS-CoV', 'type': 5, 'target': 'ORF8'},
#  {'source': 'Bat coronavirus', 'type': 6, 'target': 'SARS-CoV-2'},
#  {'source': 'Bat coronavirus', 'type': 5, 'target': 'Spike'},
#  {'source': 'Bat coronavirus', 'type': 5, 'target': 'ORF8'},
#  {'source': 'Beta coronavirus', 'type': 6, 'target': 'sarbeco virus'},
#  {'source': 'Beta coronavirus', 'type': 5, 'target': 'Mpro'},
#  {'source': 'Beta coronavirus', 'type': 5, 'target': 'Spike'},
#  {'source': 'Beta coronavirus', 'type': 5, 'target': 'E'},
#  {'source': 'SARS-related CoVs', 'type': 4, 'target': 'ACE2'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'COVID-19'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'acute respiratory syndrome'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'death'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'human respiratory disease'},
#  {'source': 'SARS-CoV-2',
#   'type': 0,
#   'target': 'severe humanrespiratory disease'},
#  {'source': 'SARS-CoV-2',
#   'type': 0,
#   'target': 'severe pneumonia in patients with weaker immune system'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'cough'},
#  {'source': 'SARS-CoV-2',
#   'type': 0,
#   'target': 'epidemic of acute respiratory syndrome in humans'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'pneumonia'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'severe pneumonia'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'severe respiratory infection'},
#  {'source': 'SARS-CoV-2', 'type': 0, 'target': 'atypical pneumonia'},
#  {'source': 'SARS-CoV-2', 'type': 4, 'target': 'ACE2'},
#  {'source': 'SARS-CoV-2', 'type': 4, 'target': 'TMPRSS2'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Nsp7'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF6'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF1ab'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Mpro'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF7a'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF10'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Spike'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF1b'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Nsp3'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'E'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF3a'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'N'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF1a'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Nsp1'},
#  {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF8'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'sarbeco virus'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat coronavirus RaTG13'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat-SL-CoVZX45'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'MERS-CoV'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat SARS-CoV'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'SARS-CoV-like Coronaviruses'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat-SL-CoVZXC21'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat coronavirus'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat SARS-like Coronaviruses'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat-like SARS coronavirus'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'SARS-CoV'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat SARSr-Cov'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat-SL-CoVZX21'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat-SL-CoVZC45'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Beta coronavirus'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'SARS-related CoVs'},
#  {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat SARS-CoV-like'},
#  {'source': 'lentiviruses', 'type': 5, 'target': 'Spike'},
#  {'source': 'lentiviruses', 'type': 4, 'target': 'ACE2'},
#  {'source': 'feline coronavirus', 'type': 5, 'target': 'Spike'},
#  {'source': 'HIV', 'type': 5, 'target': 'Spike'},
#  {'source': 'Bat SARS-like Coronaviruses', 'type': 6, 'target': 'SARS-CoV-2'},
#  {'source': 'SARS-CoV-like Coronaviruses', 'type': 6, 'target': 'SARS-CoV'},
#  {'source': 'MERS-CoV', 'type': 6, 'target': 'Beta coronavirus'},
#  {'source': 'MERS-CoV', 'type': 5, 'target': 'Mpro'},
#  {'source': 'MERS-CoV', 'type': 5, 'target': 'Nsp3'},
#  {'source': 'MERS-CoV', 'type': 5, 'target': 'Spike'},
#  {'source': 'MERS-CoV', 'type': 4, 'target': 'DPP4'},
#  {'source': 'MERS-CoV', 'type': 4, 'target': 'ACE2'},
#  {'source': 'MERS-CoV', 'type': 0, 'target': 'MERS'},
#  {'source': 'MERS-CoV', 'type': 0, 'target': 'epidemic'},
#  {'source': 'MERS-CoV',
#   'type': 0,
#   'target': 'severe and potential fatal respiratory tract infections'},
#  {'source': 'Spike', 'type': 3, 'target': 'ACE2'},
#  {'source': 'Spike', 'type': 3, 'target': 'O-acetylated sialic acid'},
#  {'source': 'Spike', 'type': 3, 'target': 'trypsin'}]

# %%
nodes=pd.read_csv('csv/nodes.csv')

# %%
nodes['name']=nodes['node'].apply(lambda x:find_id(x))
nodes['id']=nodes['node'].apply(lambda x:find_label(x))

# %%
classes=pd.read_csv('csv/type.csv')
classes=classes[['@id','type']]
classes=classes.set_index('@id')['type']
classes
# Out:
# @id
# C1          rdf-schema#Class
# C2          rdf-schema#Class
# C3          rdf-schema#Class
# C4          rdf-schema#Class
# C5          rdf-schema#Class
#                   ...
# R5001200                 C25
# R5001201                 C25
# R5001202                 C25
# R5001203                 C25
# R5001204                 C25
# Name: type, Length: 1291, dtype: object

# %%
nodes['class']=nodes['name'].apply(lambda x:classes.loc[x])
nodes['size']=nodes['id'].apply(lambda x:int(find_weight(x)+1))

# %%
del nodes['node']

# %%
relation['nodes']=list(nodes.T.to_dict().values())

# %%
relation
# Out:
# {'links': [{'source': 'neutralizing antibody m396',
#    'type': 1,
#    'target': 'SARS-CoV'},
#   {'source': 'ritonavir', 'type': 2, 'target': 'Nsp3'},
#   {'source': 'ritonavir', 'type': 2, 'target': 'Mpro'},
#   {'source': 'zopiclone', 'type': 2, 'target': 'Mpro'},
#   {'source': 'colistin', 'type': 2, 'target': 'Mpro'},
#   {'source': 'pitavastatin', 'type': 2, 'target': 'Mpro'},
#   {'source': 'pitavastatin', 'type': 1, 'target': 'SARS-CoV-2'},
#   {'source': 'Bictegravir', 'type': 2, 'target': 'Mpro'},
#   {'source': 'praziquantel', 'type': 2, 'target': 'Mpro'},
#   {'source': 'praziquantel', 'type': 1, 'target': 'SARS-CoV-2'},
#   {'source': 'lopinavir', 'type': 2, 'target': 'Nsp3'},
#   {'source': 'lopinavir', 'type': 2, 'target': 'Mpro'},
#   {'source': 'antibody m396', 'type': 2, 'target': 'Spike'},
#   {'source': 'monoclonal antibody', 'type': 2, 'target': 'Spike'},
#   {'source': 'monoclonal antibody', 'type': 1, 'target': 'SARS-CoV'},
#   {'source': 'SARS-CoV antibody', 'type': 2, 'target': 'Spike'},
#   {'source': 'SARS-CoV antibody', 'type': 1, 'target': 'SARS-CoV-2'},
#   {'source': 'SARS-CoV antibody', 'type': 1, 'target': 'SARS-CoV'},
#   {'source': 'lopinavir/ritonavir', 'type': 2, 'target': 'Mpro'},
#   {'source': 'B-M27-VME', 'type': 2, 'target': 'Nsp3'},
#   {'source': 'CR3022', 'type': 2, 'target': 'Spike'},
#   {'source': 'CR3022', 'type': 1, 'target': 'SARS-CoV-2'},
#   {'source': 'perampanel', 'type': 2, 'target': 'Mpro'},
#   {'source': 'perampanel', 'type': 1, 'target': 'SARS-CoV-2'},
#   {'source': 'Prulifloxacin', 'type': 2, 'target': 'Mpro'},
#   {'source': 'MERS-CoV-specific human monoclonal antibody m336',
#    'type': 2,
#    'target': 'Spike'},
#   {'source': 'Sofosbuvir/Velpatasvir', 'type': 1, 'target': 'MERS-CoV'},
#   {'source': 'Sofosbuvir/Velpatasvir', 'type': 1, 'target': 'SARS-CoV-2'},
#   {'source': 'Sofosbuvir/Velpatasvir', 'type': 1, 'target': 'Coronaviruses'},
#   {'source': 'eszopiclone', 'type': 2, 'target': 'Mpro'},
#   {'source': 'nelfinavir', 'type': 2, 'target': 'Mpro'},
#   {'source': 'nelfinavir', 'type': 1, 'target': 'Coronaviruses'},
#   {'source': 'nelfinavir', 'type': 1, 'target': 'SARS-CoV-2'},
#   {'source': 'porcine epidemic diarrhea virus', 'type': 5, 'target': 'Spike'},
#   {'source': 'Murine coronavirus', 'type': 5, 'target': 'Nsp3'},
#   {'source': 'Coronaviruses', 'type': 0, 'target': 'severe'},
#   {'source': 'Coronaviruses', 'type': 0, 'target': 'common cold'},
#   {'source': 'Coronaviruses', 'type': 0, 'target': 'severe pneumonia'},
#   {'source': 'Coronaviruses',
#    'type': 0,
#    'target': 'gastrointestinal diseases'},
#   {'source': 'Coronaviruses', 'type': 4, 'target': 'ACE2'},
#   {'source': 'Coronaviruses', 'type': 5, 'target': 'Nsp3'},
#   {'source': 'Coronaviruses', 'type': 5, 'target': 'Mpro'},
#   {'source': 'Coronaviruses', 'type': 5, 'target': 'E'},
#   {'source': 'Coronaviruses', 'type': 5, 'target': 'ORF1a'},
#   {'source': 'Coronaviruses', 'type': 5, 'target': 'ORF1ab'},
#   {'source': 'Coronaviruses', 'type': 5, 'target': 'ORF1b'},
#   {'source': 'Coronaviruses', 'type': 5, 'target': 'Spike'},
#   {'source': 'Coronaviruses', 'type': 6, 'target': 'MERS-CoV'},
#   {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'bat-SL-CoVZX21'},
#   {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'SARS-CoV'},
#   {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'Bat coronavirus'},
#   {'source': 'bat SARS-CoV-like', 'type': 6, 'target': 'bat-SL-CoVZX45'},
#   {'source': 'bat SARS-CoV-like', 'type': 5, 'target': 'Spike'},
#   {'source': 'bat SARS-CoV-like', 'type': 4, 'target': 'ACE2'},
#   {'source': 'SARS-CoV', 'type': 0, 'target': 'severe respiratory disease'},
#   {'source': 'SARS-CoV',
#    'type': 0,
#    'target': 'severe respiratory diseases in afflicted human patients'},
#   {'source': 'SARS-CoV', 'type': 0, 'target': 'epidemic'},
#   {'source': 'SARS-CoV', 'type': 0, 'target': 'SARS'},
#   {'source': 'SARS-CoV', 'type': 4, 'target': 'TMPRSS2'},
#   {'source': 'SARS-CoV', 'type': 4, 'target': 'ACE2'},
#   {'source': 'SARS-CoV', 'type': 5, 'target': 'Spike'},
#   {'source': 'SARS-CoV', 'type': 5, 'target': 'ORF1ab'},
#   {'source': 'SARS-CoV', 'type': 5, 'target': 'Nsp3'},
#   {'source': 'SARS-CoV', 'type': 5, 'target': 'E'},
#   {'source': 'SARS-CoV', 'type': 5, 'target': 'Nsp1'},
#   {'source': 'SARS-CoV', 'type': 5, 'target': 'Mpro'},
#   {'source': 'SARS-CoV', 'type': 5, 'target': 'N'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'Bat-SL-CoVZC45'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'Bat SARS-CoV'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'MERS-CoV'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'Bat-SL-CoVZXC21'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'Beta coronavirus'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'SARS-CoV-2'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'bat SARS-CoV-like'},
#   {'source': 'SARS-CoV', 'type': 6, 'target': 'SARS-CoV-like Coronaviruses'},
#   {'source': 'murine hepatitis virus', 'type': 5, 'target': 'Nsp3'},
#   {'source': 'bat SARS CoV W1V1', 'type': 4, 'target': 'ACE2'},
#   {'source': 'sarbeco virus', 'type': 5, 'target': 'Spike'},
#   {'source': 'Bat-SL-CoVZC45', 'type': 5, 'target': 'Nsp7'},
#   {'source': 'Bat-SL-CoVZC45', 'type': 5, 'target': 'E'},
#   {'source': 'bat-associated betacoronavirus', 'type': 4, 'target': 'ACE2'},
#   {'source': 'SARS-CoV BJ01', 'type': 6, 'target': 'bat SARSr-CoV WIV1'},
#   {'source': 'mouse hepatitis virus', 'type': 5, 'target': 'Nsp3'},
#   {'source': 'Bat SARS-CoV', 'type': 5, 'target': 'ORF8'},
#   {'source': 'Bat coronavirus', 'type': 6, 'target': 'SARS-CoV-2'},
#   {'source': 'Bat coronavirus', 'type': 5, 'target': 'Spike'},
#   {'source': 'Bat coronavirus', 'type': 5, 'target': 'ORF8'},
#   {'source': 'Beta coronavirus', 'type': 6, 'target': 'sarbeco virus'},
#   {'source': 'Beta coronavirus', 'type': 5, 'target': 'Mpro'},
#   {'source': 'Beta coronavirus', 'type': 5, 'target': 'Spike'},
#   {'source': 'Beta coronavirus', 'type': 5, 'target': 'E'},
#   {'source': 'SARS-related CoVs', 'type': 4, 'target': 'ACE2'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'COVID-19'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'acute respiratory syndrome'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'death'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'human respiratory disease'},
#   {'source': 'SARS-CoV-2',
#    'type': 0,
#    'target': 'severe humanrespiratory disease'},
#   {'source': 'SARS-CoV-2',
#    'type': 0,
#    'target': 'severe pneumonia in patients with weaker immune system'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'cough'},
#   {'source': 'SARS-CoV-2',
#    'type': 0,
#    'target': 'epidemic of acute respiratory syndrome in humans'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'pneumonia'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'severe pneumonia'},
#   {'source': 'SARS-CoV-2',
#    'type': 0,
#    'target': 'severe respiratory infection'},
#   {'source': 'SARS-CoV-2', 'type': 0, 'target': 'atypical pneumonia'},
#   {'source': 'SARS-CoV-2', 'type': 4, 'target': 'ACE2'},
#   {'source': 'SARS-CoV-2', 'type': 4, 'target': 'TMPRSS2'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Nsp7'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF6'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF1ab'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Mpro'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF7a'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF10'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Spike'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF1b'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Nsp3'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'E'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF3a'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'N'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF1a'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'Nsp1'},
#   {'source': 'SARS-CoV-2', 'type': 5, 'target': 'ORF8'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'sarbeco virus'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat coronavirus RaTG13'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat-SL-CoVZX45'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'MERS-CoV'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat SARS-CoV'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'SARS-CoV-like Coronaviruses'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat-SL-CoVZXC21'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat coronavirus'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat SARS-like Coronaviruses'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat-like SARS coronavirus'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'SARS-CoV'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat SARSr-Cov'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat-SL-CoVZX21'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Bat-SL-CoVZC45'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'Beta coronavirus'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'SARS-related CoVs'},
#   {'source': 'SARS-CoV-2', 'type': 6, 'target': 'bat SARS-CoV-like'},
#   {'source': 'lentiviruses', 'type': 5, 'target': 'Spike'},
#   {'source': 'lentiviruses', 'type': 4, 'target': 'ACE2'},
#   {'source': 'feline coronavirus', 'type': 5, 'target': 'Spike'},
#   {'source': 'HIV', 'type': 5, 'target': 'Spike'},
#   {'source': 'Bat SARS-like Coronaviruses', 'type': 6, 'target': 'SARS-CoV-2'},
#   {'source': 'SARS-CoV-like Coronaviruses', 'type': 6, 'target': 'SARS-CoV'},
#   {'source': 'MERS-CoV', 'type': 6, 'target': 'Beta coronavirus'},
#   {'source': 'MERS-CoV', 'type': 5, 'target': 'Mpro'},
#   {'source': 'MERS-CoV', 'type': 5, 'target': 'Nsp3'},
#   {'source': 'MERS-CoV', 'type': 5, 'target': 'Spike'},
#   {'source': 'MERS-CoV', 'type': 4, 'target': 'DPP4'},
#   {'source': 'MERS-CoV', 'type': 4, 'target': 'ACE2'},
#   {'source': 'MERS-CoV', 'type': 0, 'target': 'MERS'},
#   {'source': 'MERS-CoV', 'type': 0, 'target': 'epidemic'},
#   {'source': 'MERS-CoV',
#    'type': 0,
#    'target': 'severe and potential fatal respiratory tract infections'},
#   {'source': 'Spike', 'type': 3, 'target': 'ACE2'},
#   {'source': 'Spike', 'type': 3, 'target': 'O-acetylated sialic acid'},
#   {'source': 'Spike', 'type': 3, 'target': 'trypsin'}],
#  'nodes': [{'name': 'R5000054',
#    'id': 'neutralizing antibody m396',
#    'class': 'C21',
#    'size': 1},
#   {'name': 'R5000055', 'id': 'ritonavir', 'class': 'C21', 'size': 2},
#   {'name': 'R5000056', 'id': 'zopiclone', 'class': 'C21', 'size': 1},
#   {'name': 'R5000057', 'id': 'colistin', 'class': 'C21', 'size': 2},
#   {'name': 'R5000058', 'id': 'pitavastatin', 'class': 'C21', 'size': 2},
#   {'name': 'R5000059', 'id': 'Bictegravir', 'class': 'C21', 'size': 1},
#   {'name': 'R5000060', 'id': 'praziquantel', 'class': 'C21', 'size': 2},
#   {'name': 'R5000061', 'id': 'lopinavir', 'class': 'C21', 'size': 2},
#   {'name': 'R5000062', 'id': 'antibody m396', 'class': 'C21', 'size': 1},
#   {'name': 'R5000063', 'id': 'monoclonal antibody', 'class': 'C21', 'size': 2},
#   {'name': 'R5000064', 'id': 'SARS-CoV antibody', 'class': 'C21', 'size': 2},
#   {'name': 'R5000065', 'id': 'lopinavir/ritonavir', 'class': 'C21', 'size': 2},
#   {'name': 'R5000066', 'id': 'B-M27-VME', 'class': 'C21', 'size': 1},
#   {'name': 'R5000067', 'id': 'CR3022', 'class': 'C21', 'size': 2},
#   {'name': 'R5000068', 'id': 'perampanel', 'class': 'C21', 'size': 2},
#   {'name': 'R5000069', 'id': 'Prulifloxacin', 'class': 'C21', 'size': 1},
#   {'name': 'R5000070',
#    'id': 'MERS-CoV-specific human monoclonal antibody m336',
#    'class': 'C21',
#    'size': 1},
#   {'name': 'R5000071',
#    'id': 'Sofosbuvir/Velpatasvir',
#    'class': 'C21',
#    'size': 2},
#   {'name': 'R5000072', 'id': 'eszopiclone', 'class': 'C21', 'size': 1},
#   {'name': 'R5000073', 'id': 'nelfinavir', 'class': 'C21', 'size': 3},
#   {'name': 'R5000002',
#    'id': 'porcine epidemic diarrhea virus',
#    'class': 'C1',
#    'size': 1},
#   {'name': 'R5000003', 'id': 'Murine coronavirus', 'class': 'C1', 'size': 1},
#   {'name': 'R5000006', 'id': 'Coronaviruses', 'class': 'C1', 'size': 4},
#   {'name': 'R5000007', 'id': 'bat SARS-CoV-like', 'class': 'C1', 'size': 3},
#   {'name': 'R5000010', 'id': 'SARS-CoV', 'class': 'C1', 'size': 6},
#   {'name': 'R5000011',
#    'id': 'murine hepatitis virus',
#    'class': 'C1',
#    'size': 1},
#   {'name': 'R5000013', 'id': 'bat SARS CoV W1V1', 'class': 'C1', 'size': 1},
#   {'name': 'R5000015', 'id': 'sarbeco virus', 'class': 'C1', 'size': 3},
#   {'name': 'R5000016', 'id': 'Bat-SL-CoVZC45', 'class': 'C1', 'size': 3},
#   {'name': 'R5000017',
#    'id': 'bat-associated betacoronavirus',
#    'class': 'C1',
#    'size': 1},
#   {'name': 'R5000018', 'id': 'SARS-CoV BJ01', 'class': 'C1', 'size': 1},
#   {'name': 'R5000019',
#    'id': 'mouse hepatitis virus',
#    'class': 'C1',
#    'size': 1},
#   {'name': 'R5000020', 'id': 'Bat SARS-CoV', 'class': 'C1', 'size': 2},
#   {'name': 'R5000022', 'id': 'Bat coronavirus', 'class': 'C1', 'size': 3},
#   {'name': 'R5000023', 'id': 'Beta coronavirus', 'class': 'C1', 'size': 3},
#   {'name': 'R5000024', 'id': 'SARS-related CoVs', 'class': 'C1', 'size': 2},
#   {'name': 'R5000025', 'id': 'SARS-CoV-2', 'class': 'C1', 'size': 7},
#   {'name': 'R5000026', 'id': 'lentiviruses', 'class': 'C1', 'size': 2},
#   {'name': 'R5000027', 'id': 'feline coronavirus', 'class': 'C1', 'size': 1},
#   {'name': 'R5000028', 'id': 'HIV', 'class': 'C1', 'size': 1},
#   {'name': 'R5000030',
#    'id': 'Bat SARS-like Coronaviruses',
#    'class': 'C1',
#    'size': 3},
#   {'name': 'R5000031',
#    'id': 'SARS-CoV-like Coronaviruses',
#    'class': 'C1',
#    'size': 3},
#   {'name': 'R5000033', 'id': 'MERS-CoV', 'class': 'C1', 'size': 4},
#   {'name': 'R5000045', 'id': 'Spike', 'class': 'C19', 'size': 5},
#   {'name': 'R5000038', 'id': 'Nsp3', 'class': 'C19', 'size': 4},
#   {'name': 'R5000036', 'id': 'Mpro', 'class': 'C19', 'size': 5},
#   {'name': 'R5000085', 'id': 'severe', 'class': 'C23', 'size': 1},
#   {'name': 'R5000080', 'id': 'common cold', 'class': 'C23', 'size': 2},
#   {'name': 'R5000074', 'id': 'severe pneumonia', 'class': 'C23', 'size': 2},
#   {'name': 'R5000088',
#    'id': 'gastrointestinal diseases',
#    'class': 'C23',
#    'size': 1},
#   {'name': 'R5000053', 'id': 'ACE2', 'class': 'C20', 'size': 5},
#   {'name': 'R5000035', 'id': 'E', 'class': 'C19', 'size': 3},
#   {'name': 'R5000034', 'id': 'ORF1a', 'class': 'C19', 'size': 2},
#   {'name': 'R5000037', 'id': 'ORF1ab', 'class': 'C19', 'size': 2},
#   {'name': 'R5000046', 'id': 'ORF1b', 'class': 'C19', 'size': 2},
#   {'name': 'R5000009', 'id': 'bat-SL-CoVZX21', 'class': 'C1', 'size': 2},
#   {'name': 'R5000004', 'id': 'bat-SL-CoVZX45', 'class': 'C1', 'size': 2},
#   {'name': 'R5000082',
#    'id': 'severe respiratory disease',
#    'class': 'C23',
#    'size': 1},
#   {'name': 'R5000077',
#    'id': 'severe respiratory diseases in afflicted human patients',
#    'class': 'C23',
#    'size': 1},
#   {'name': 'R5000076', 'id': 'epidemic', 'class': 'C23', 'size': 1},
#   {'name': 'R5000093', 'id': 'SARS', 'class': 'C23', 'size': 1},
#   {'name': 'R5000052', 'id': 'TMPRSS2', 'class': 'C20', 'size': 2},
#   {'name': 'R5000043', 'id': 'Nsp1', 'class': 'C19', 'size': 1},
#   {'name': 'R5000039', 'id': 'N', 'class': 'C19', 'size': 3},
#   {'name': 'R5000012', 'id': 'Bat-SL-CoVZXC21', 'class': 'C1', 'size': 2},
#   {'name': 'R5000048', 'id': 'Nsp7', 'class': 'C19', 'size': 1},
#   {'name': 'R5000005', 'id': 'bat SARSr-CoV WIV1', 'class': 'C1', 'size': 1},
#   {'name': 'R5000040', 'id': 'ORF8', 'class': 'C19', 'size': 2},
#   {'name': 'R5000086', 'id': 'COVID-19', 'class': 'C23', 'size': 2},
#   {'name': 'R5000075',
#    'id': 'acute respiratory syndrome',
#    'class': 'C23',
#    'size': 1},
#   {'name': 'R5000087', 'id': 'death', 'class': 'C23', 'size': 2},
#   {'name': 'R5000089',
#    'id': 'human respiratory disease',
#    'class': 'C23',
#    'size': 2},
#   {'name': 'R5000092',
#    'id': 'severe humanrespiratory disease',
#    'class': 'C23',
#    'size': 1},
#   {'name': 'R5000081',
#    'id': 'severe pneumonia in patients with weaker immune system',
#    'class': 'C23',
#    'size': 1},
#   {'name': 'R5000091', 'id': 'cough', 'class': 'C23', 'size': 1},
#   {'name': 'R5000094',
#    'id': 'epidemic of acute respiratory syndrome in humans',
#    'class': 'C23',
#    'size': 2},
#   {'name': 'R5000079', 'id': 'pneumonia', 'class': 'C23', 'size': 4},
#   {'name': 'R5000090',
#    'id': 'severe respiratory infection',
#    'class': 'C23',
#    'size': 2},
#   {'name': 'R5000083', 'id': 'atypical pneumonia', 'class': 'C23', 'size': 2},
#   {'name': 'R5000047', 'id': 'ORF6', 'class': 'C19', 'size': 1},
#   {'name': 'R5000041', 'id': 'ORF7a', 'class': 'C19', 'size': 1},
#   {'name': 'R5000042', 'id': 'ORF10', 'class': 'C19', 'size': 1},
#   {'name': 'R5000044', 'id': 'ORF3a', 'class': 'C19', 'size': 1},
#   {'name': 'R5000032',
#    'id': 'bat coronavirus RaTG13',
#    'class': 'C1',
#    'size': 2},
#   {'name': 'R5000029',
#    'id': 'bat-like SARS coronavirus',
#    'class': 'C1',
#    'size': 1},
#   {'name': 'R5000014', 'id': 'bat SARSr-Cov', 'class': 'C1', 'size': 1},
#   {'name': 'R5000051', 'id': 'DPP4', 'class': 'C20', 'size': 1},
#   {'name': 'R5000078', 'id': 'MERS', 'class': 'C23', 'size': 1},
#   {'name': 'R5000084',
#    'id': 'severe and potential fatal respiratory tract infections',
#    'class': 'C23',
#    'size': 1},
#   {'name': 'R5000050',
#    'id': 'O-acetylated sialic acid',
#    'class': 'C20',
#    'size': 1},
#   {'name': 'R5000049', 'id': 'trypsin', 'class': 'C20', 'size': 1}]}

# %%
with open('relation.json', 'w') as fp:
    json.dump(relation, fp)

# %%
a=[1,2,3,4,5,6,7]
np.log(a)+0.5
# Out:
# array([0.5       , 1.19314718, 1.59861229, 1.88629436, 2.10943791,
#        2.29175947, 2.44591015])
